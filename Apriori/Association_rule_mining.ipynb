# %% [markdown]
# # Association Rule Mining

# %% [markdown]
# ![alt text](arl.png "include arl image")

# %% [markdown]
# ### Apriori implementaion in python

# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#import dataset
dataset = pd.read_csv('Market_Basket_Optimisation.csv',header = None)

# %%
# See top rows of data
dataset.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# ...

# %% [markdown]
# Dataset for Apriori is in the form of list of lists.

# %%
dataset.length()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-0197f5448b66> in <module>
# ----> 1 dataset.length()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'length'

# %%
dataset[0]
# Out:
# 0                  shrimp
# 1                 burgers
# 2                 chutney
# 3                  turkey
# 4           mineral water
# 5          low fat yogurt
# 6       whole wheat pasta
# 7                    soup
# 8       frozen vegetables
# 9            french fries
# 10                   eggs
# 11                cookies
# 12                 turkey
# 13              spaghetti
# 14          mineral water
# 15          mineral water
# 16                 shrimp
# 17                 turkey
# 18                 turkey
# 19              meatballs
# 20               red wine
# 21                   rice
# 22              spaghetti
# 23                burgers
# 24                   eggs
# 25        parmesan cheese
# 26            ground beef
# 27        sparkling water
# 28          mineral water
# 29      frozen vegetables
#               ...
# 7471        mineral water
# 7472            chocolate
# 7473     whole wheat rice
# 7474               turkey
# 7475               turkey
# ...
